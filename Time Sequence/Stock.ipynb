# %%
import time
import random, os, sys
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.python.keras.layers import Layer
import numpy
import matplotlib.pyplot as plt
import pandas
import os 
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Model, load_model
from tqdm import trange
import tensorflow.keras.layers as layers
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, Embedding, Input, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop


from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
import datetime
from scipy.stats import pearsonr
from tensorflow import keras
from keras import layers
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
DATA_DIR = 'IBM Stock Data.csv'
# load the dataset
#使用 pandas 库的 read_csv 函数从指定路径 datasource 加载 csv 格式的数据。
d= pandas.read_csv(DATA_DIR)
d.columns = ["Date", "Time", "Open", "Low","Close"]
d
# Out:
#              Date   Time        Open         Low       Close
# 0       3/25/2022  19:19  131.300000  131.300000  131.300000
# 1       3/25/2022  19:18  131.300000  131.300000  131.300000
# 2       3/25/2022  17:50  131.300000  131.300000  131.300000
# 3       3/25/2022  16:59  131.340000  131.340000  131.350000
# 4       3/25/2022  16:42  131.326000  131.326000  131.350000
# ...           ...    ...         ...         ...         ...
# 216877   4/6/2020   7:27   95.385037   95.385037   95.385037
# 216878   4/6/2020   7:25   94.530379   94.530379   94.530379
# 216879   4/6/2020   7:08   94.703037   94.703037   94.703037
# 216880   4/6/2020   7:02   95.479999   95.479999   95.479999
# 216881   4/6/2020   7:01   94.979290   94.979290   94.979290
#
# [216882 rows x 5 columns]

# %%
d['Date'] = pandas.to_datetime(d['Date']+' '+d['Time'])
d = d.set_index('Date')

# %%
d = d.drop(columns=['Time'])
d
# Out:
#                            Open         Low       Close
# Date
# 2022-03-25 19:19:00  131.300000  131.300000  131.300000
# 2022-03-25 19:18:00  131.300000  131.300000  131.300000
# 2022-03-25 17:50:00  131.300000  131.300000  131.300000
# 2022-03-25 16:59:00  131.340000  131.340000  131.350000
# 2022-03-25 16:42:00  131.326000  131.326000  131.350000
# ...                         ...         ...         ...
# 2020-04-06 07:27:00   95.385037   95.385037   95.385037
# 2020-04-06 07:25:00   94.530379   94.530379   94.530379
# 2020-04-06 07:08:00   94.703037   94.703037   94.703037
# 2020-04-06 07:02:00   95.479999   95.479999   95.479999
# 2020-04-06 07:01:00   94.979290   94.979290   94.979290
#
# [216882 rows x 3 columns]

# %%
dataset_1=d[['Open']]
print(dataset_1)
dataset_2=d[['Low']]
print(dataset_2)
dataset_3=d[['Close']]
print(dataset_3)
# Out:
# [[131.3  ]
#  [131.3  ]
#  [131.3  ]
#  ...
#  [126.125]
#  [126.1  ]
#  [126.055]]
# [[131.3  ]
#  [131.3  ]
#  [131.3  ]
#  ...
#  [126.125]
#  [125.99 ]
#  [126.02 ]]
# [[131.3   ]
#  [131.3   ]
#  [131.3   ]
#  ...
#  [126.16  ]
#  [126.0702]
#  [126.07  ]]

# %%
def plot_dataset(Dataset: str,X,Y):
    plt.figure(figsize = (36,18))
    plt.tick_params(labelsize=19)
    #plt.xticks(range(0,df.shape[0],500),df['Date'].loc[::500],rotation=45)
    #给当前图表添加一个 x 轴标签，标签内容为 'Date_Time'，字体大小为 18。
    plt.xlabel(X,fontsize=36)
    #给当前图表添加一个 y 轴标签，标签内容为 'Close Price'，字体大小为 18。
    plt.ylabel(Y,fontsize=36)
    plt.plot(range(Dataset.shape[0]),Dataset)
    plt.show()
    return plt.show()
#CPU
plot_dataset(dataset_1,"Time","Open")
#MEM
plot_dataset(dataset_2,"Time","Low")

plot_dataset(dataset_3,"Time","Close")

# %%
# normalize the dataset
#将数据缩放到0到1之间。
scaler_1 = MinMaxScaler(feature_range=(0, 1)).fit(dataset_1)
scaler_2 = MinMaxScaler(feature_range=(0, 1)).fit(dataset_2)
scaler_3 = MinMaxScaler(feature_range=(0, 1)).fit(dataset_3)
#fit_transform()方法在拟合数据的同时对数据进行缩放并返回缩放后的数组。
#dataset = scaler.fit_transform(dataset)
Dataset_1 = scaler_1.transform(dataset_1)
Dataset_2 = scaler_2.transform(dataset_2)
Dataset_3 = scaler_3.transform(dataset_3)
# plot_dataset(Dataset_1,time,"Time","CPU Normal")
# plot_dataset(Dataset_2,time,"Time","MEM Normal")
plot_dataset(Dataset_1,"Time","Open")
plot_dataset(Dataset_2,"Time","Low")
plot_dataset(Dataset_2,"Time","Close")

# %%
def split_dataset(dataset, iltrain) :
    split = int(len(dataset) * iltrain)
    #取 dataset 数组中第 0 行到第 train_size-1 行的所有列数据，作为训练集。 
    #取 dataset 数组中从第 train_size-look_back 行到最后一行的所有列，即测试集。
    train = dataset[:split]
    test = dataset[split:]
    #train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]
    print('train_dataset: {}, test_dataset: {}'.format(len(train), len(test)))
    return train, test
#CPU
train_dataset , test_dataset = split_dataset(Dataset_1 , 0.8)
##MEM
train_dataset2 , test_dataset2 = split_dataset(Dataset_2 , 0.8)
##MEM
train_dataset3 , test_dataset3 = split_dataset(Dataset_3 , 0.8)
# Out:
# train_dataset: 5506, test_dataset: 1377
# train_dataset: 5506, test_dataset: 1377
# train_dataset: 5506, test_dataset: 1377

# %%
# how long preceding sequence to consider for prediction
#将连续的60天的数据作为输入，然后预测第61天的收盘价。
SEQ_LEN = 64            
# How far into the future we are making prediction(10 min in this case)
#用未来10个单位的时间来预测当前的股价变化。
FUTURE_PERIOD = 16
#指定要预测的是什么变量。
RATIO_TO_PREDICT = "Close"

def create_dataset(dataset: numpy.ndarray):
    data_x = []
    data_y = []
    for i in range(len(dataset)-FUTURE_PERIOD):
        #提取从第 i 行到第 i+look_back-1 行（即长度为 look_back）的第 0 列数据。第一维度切片！
        a = dataset[i:(i+FUTURE_PERIOD), 0]
        data_x.append(a)
        #提取第 i+look_back 行的第0列数据，用作训练数据对应的标签。
        b = dataset[(i + FUTURE_PERIOD), 0]    #最终y少了最前面的 look_back个数据
        data_y.append(b)
    #返回值是一个元组，包含两个 NumPy 数组。
    #第一个数组 X 是输入特征，其形状为 (samples, look_back, features)，samples代表样本数，look_back代表每个样本包含的时间步数，features 代表每个时间步的特征数。
    #第二个数组 y 是输出标签，其形状为 (samples, 1)，其中 samples 代表样本数，1 代表每个样本的输出值。
    return numpy.array(data_x), numpy.array(data_y) 
#CPU
train_x,train_y = create_dataset(train_dataset)    
test_x,test_y = create_dataset(test_dataset)
#MEM
train_x2,train_y2 = create_dataset(train_dataset2)    
test_x2,test_y2 = create_dataset(test_dataset2)
#MEM
train_x3,train_y3 = create_dataset(train_dataset3)    
test_x3,test_y3 = create_dataset(test_dataset3)

# %%
#CPU
train_x = numpy.reshape(train_x, (train_x.shape[0] , train_x.shape[1]))
test_x = numpy.reshape(test_x, (test_x.shape[0] , test_x.shape[1], 1))
train_y = numpy.reshape(train_y, (train_y.shape[0] ))
test_y = numpy.reshape(test_y, (test_y.shape[0]))
print(train_x.shape)
print(test_y.shape)
#MEM
train_x2 = numpy.reshape(train_x2, (train_x2.shape[0] , train_x2.shape[1]))
test_x2 = numpy.reshape(test_x2, (test_x2.shape[0] , test_x2.shape[1], 1))
train_y2 = numpy.reshape(train_y2, (train_y2.shape[0] ))
test_y2 = numpy.reshape(test_y2, (test_y2.shape[0]))
print(train_x2.shape)
print(test_y2.shape)
#MEM
train_x3 = numpy.reshape(train_x3, (train_x3.shape[0] , train_x3.shape[1]))
test_x3 = numpy.reshape(test_x3, (test_x3.shape[0] , test_x3.shape[1]))
train_y3 = numpy.reshape(train_y3, (train_y3.shape[0] ))
test_y3 = numpy.reshape(test_y3, (test_y3.shape[0]))
print(train_x3.shape)
print(test_y3.shape)
# Out:
# (5490, 16)
# (1361,)
# (5490, 16)
# (1361,)
# (5490, 16)
# (1361,)

# %%
times1 = int(train_y.shape[0])    #训练集的时间序列大小 
times2 = int(test_y.shape[0])      #测试集的时间序列大小 
def plot_data(Time1,    
              Time2, 
              train_y: numpy.ndarray,    #训练集上的预测值
              test_y: numpy.ndarray,     #测试集上的预测值。
              X: str,
              Y: str):#整个数据集上的预测值。

    plt.figure(figsize = (36,18))
    plt.tick_params(labelsize=19)
    #plt.xticks(range(0,df.shape[0],500),df['Date'].loc[::500],rotation=45)
    #给当前图表添加一个 x 轴标签，标签内容为 'Date_Time'，字体大小为 18。
    plt.xlabel(X,fontsize=36)
    #给当前图表添加一个 y 轴标签，标签内容为 'Close Price'，字体大小为 18。
    plt.ylabel(Y,fontsize=36)
    #展示了预测结果和原始数据的对比。
    #原始数据的折线图
    #训练数据的预测结果的折线图，其横坐标的前look_back个点为空，因为模型在这个时候还没有进行预测
    plt.plot(range(Time1), [x for x in train_y],color='blue', label='train target')
    #测试数据的预测结果的折线图，它的横坐标与第二条曲线重合，前面也是有look_back个点为空的。
    plt.plot(range(Time1+Time2), 
             [None for _ in train_y] +
             [x for x in test_y],color='black', label='test target')
    plt.legend(loc='best',fontsize=36)
    plt.show()
#CPU
plot_data(times1,times2,train_y,test_y,"Time","Open Target")
#MEM
plot_data(times1,times2,train_y2,test_y2,"Time","Low Target")
#MEM
plot_data(times1,times2,train_y3,test_y3,"Time","Close Target")

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self,
                 head_size, 
                 num_heads, 
                 ff_dim,
                 dropout=0
                ):
        super(TransformerEncoder, self).__init__()
        self.head_size = head_size
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.dropout = dropout
        
        self.layer_norm_1 = layers.LayerNormalization(epsilon=1e-6)
        self.multihead_attention = layers.MultiHeadAttention(
            key_dim=head_size, num_heads=num_heads, dropout=dropout
        )
        self.dropout_1 = layers.Dropout(0.25)
        self.layer_norm_2 = layers.LayerNormalization(epsilon=1e-6)
        self.conv1d_1 = layers.Conv1D(filters=4, kernel_size=1, activation="relu")    #filters:过滤器的个数   kernel:核数
        self.dropout_2 = layers.Dropout(0.2)
        self.conv1d_2 = layers.Conv1D(filters=1, kernel_size=1)

    def call(self, inputs):
        # Normalization and Attention
#         print(inputs.shape)
        x = self.layer_norm_1(inputs)
#         x = tf.expand_dims(x,axis=1)
        attention_output = self.multihead_attention(x, x)
        x = self.dropout_1(attention_output)
        res = x + inputs

        # Feed Forward Part
        x = self.layer_norm_2(res)
        x = self.conv1d_1(x)

        x = self.dropout_2(x)
        x = self.conv1d_2(x)
        output = x + res
        
        return output

# %%
class attention(layers.Layer):
    def __init__(self,
                 att_size, 
                 att_heads, 
                 att_ff_dim,
                 att_dropout=0
                ):
        super(attention, self).__init__()
        self.head_size = att_size
        self.num_heads = att_heads
        self.ff_dim = att_ff_dim
        self.dropout = att_dropout
        
        self.layer_norm_1 = layers.LayerNormalization(epsilon=1e-6)
        self.multihead_attention = layers.MultiHeadAttention(
            key_dim=att_size, num_heads=att_heads, dropout=att_dropout
        )
        self.dropout_1 = layers.Dropout(0.25)
        self.layer_norm_2 = layers.LayerNormalization(epsilon=1e-6)
        self.conv1d_1 = layers.Conv1D(filters=4, kernel_size=1, activation="relu")
        self.dropout_2 = layers.Dropout(0.2)
        self.conv1d_2 = layers.Conv1D(filters=1, kernel_size=1)

    def call(self, inputs1, inputs2):
        # Normalization and Attention
#         print(inputs.shape)
#         x1 = self.layer_norm_1(inputs1)
#         x2 = self.layer_norm_1(inputs2)
        x1 = inputs1
        x2 = inputs2
#         print(x1.shape)
#         print(x2.shape)
#         x = tf.expand_dims(x,axis=1)
        attention_output = self.multihead_attention(x1, x2)
#         print(attention_output.shape)
        # 进行加权平均
#         weighted_average = tf.reduce_sum(attention_output* x2)
#         weighted_average = tf.reduce_sum(tf.multiply(attention_output, x2), axis=1)
        weighted_average = tf.multiply(attention_output, x2) + x1

#         print(weighted_average.shape)
#         #特征融合
#         x = weighted_average + x1
#         print(x.shape)
        output = weighted_average
        # Feed Forward Part
        x = self.layer_norm_2(output)
        x = self.conv1d_1(x)

        x = self.dropout_2(x)
        x = self.conv1d_2(x)
        output = x + output
#         print(output.shape)
        
        return output

# %%
class LSTMDecoder(layers.Layer):
    def __init__(self, hidden_size):
        super(LSTMDecoder, self).__init__()
        self.hidden_size = hidden_size
#         self.input_size = input_size
        
        # 创建LSTM模型
        self.Lstm1 = layers.LSTM(units = hidden_size,return_sequences=True)
        self.Dropout1 = layers.Dropout(0.2)
        self.Lstm2 = layers.LSTM(units= hidden_size,return_sequences=True)
        self.Dropout2 = layers.Dropout(0.2)
        self.Lstm3 = layers.LSTM(units = hidden_size,return_sequences=True)
        self.Dropout3 = layers.Dropout(0.2)
        self.Dense = layers.Dense(units = SEQ_LEN, activation='relu')


    def call(self, inputs):
        # 将输入通过LSTM模型
        x1 = self.Lstm1(inputs)
        x = self.Dropout1(x1)
        x2 = self.Lstm2(x)
        x = self.Lstm3(x1+x2)
        output = self.Dense(x)
        #x = self.Dense(x[:,-1,:])
        return output

# %%
def build_model():
    inp1 = Input(shape = (16,1))
    inp2 = Input(shape = (16,1))
    
    
    x1 = TransformerEncoder(head_size=256, num_heads=4, ff_dim=4, dropout=0.2)(inp1)
    x2 = TransformerEncoder(head_size=256, num_heads=4, ff_dim=4, dropout=0.2)(x1)
    x3 = TransformerEncoder(head_size=256, num_heads=4, ff_dim=4, dropout=0.2)(x2)

    
    x5 = TransformerEncoder(head_size=256, num_heads=4, ff_dim=4, dropout=0.2)(inp2)
    x6 = TransformerEncoder(head_size=256, num_heads=4, ff_dim=4, dropout=0.2)(x5)
    x7 = TransformerEncoder(head_size=256, num_heads=4, ff_dim=4, dropout=0.2)(x6)
    
    x = attention(att_size=256, att_heads=4, att_ff_dim=4, att_dropout=0.2)(x3,x7)
    
    x = LSTMDecoder(hidden_size=128)(x)
    
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    conc = concatenate([avg_pool, max_pool])
    
    x = Dense(128, activation="relu")(conc)
    x = Dense(1, activation="sigmoid")(x) 

    model = Model(inputs=[inp1, inp2], outputs = x)
    model.compile(
        loss = "mean_squared_error",  
        optimizer = keras.optimizers.Adam(learning_rate=5e-4))
    
    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 16, 1)]      0           []
#
#  input_14 (InputLayer)          [(None, 16, 1)]      0           []
#
#  transformer_encoder_6 (Transfo  (None, 16, 1)       7186        ['input_13[0][0]']
#  rmerEncoder)
#
#  transformer_encoder_9 (Transfo  (None, 16, 1)       7186        ['input_14[0][0]']
#  rmerEncoder)
#
#  transformer_encoder_7 (Transfo  (None, 16, 1)       7186        ['transformer_encoder_6[0][0]']
#  rmerEncoder)
#
#  transformer_encoder_10 (Transf  (None, 16, 1)       7186        ['transformer_encoder_9[0][0]']
#  ormerEncoder)
#
#  transformer_encoder_8 (Transfo  (None, 16, 1)       7186        ['transformer_encoder_7[0][0]']
#  rmerEncoder)
#
#  transformer_encoder_11 (Transf  (None, 16, 1)       7186        ['transformer_encoder_10[0][0]']
#  ormerEncoder)
#
#  attention_1 (attention)        (None, 16, 1)        7184        ['transformer_encoder_8[0][0]',
#                                                                   'transformer_encoder_11[0][0]']
#
#  lstm_decoder_1 (LSTMDecoder)   (None, 16, 64)       337984      ['attention_1[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 64)          0           ['lstm_decoder_1[0][0]']
#  obalAveragePooling1D)
#
#  global_max_pooling1d_1 (Global  (None, 64)          0           ['lstm_decoder_1[0][0]']
#  MaxPooling1D)
#
#  concatenate_1 (Concatenate)    (None, 128)          0           ['global_average_pooling1d_1[0][0
#                                                                  ]',
#                                                                   'global_max_pooling1d_1[0][0]']
#
#  dense_9 (Dense)                (None, 128)          16512       ['concatenate_1[0][0]']
#
#  dense_10 (Dense)               (None, 1)            129         ['dense_9[0][0]']
#
# ==================================================================================================
# Total params: 404,925
# Trainable params: 404,925
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, 
                          to_file="multi_head_net.png", 
                          show_shapes=True)

# %%
model.fit(
    [train_x3, train_x],  # 输入数据的列表，与模型的输入层顺序对应
    train_y,              # 目标数据（标签）
    validation_split=0.2,
    epochs=180,
    batch_size=64,

)
# Out:
# Epoch 1/180
# 69/69 [==============================] - 35s 288ms/step - loss: 0.0128 - val_loss: 0.0026
# Epoch 2/180
# 69/69 [==============================] - 19s 272ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 3/180
# 69/69 [==============================] - 17s 251ms/step - loss: 9.6837e-04 - val_loss: 0.0017
# Epoch 4/180
# 69/69 [==============================] - 17s 248ms/step - loss: 9.2299e-04 - val_loss: 0.0019
# Epoch 5/180
# 69/69 [==============================] - 17s 249ms/step - loss: 8.2797e-04 - val_loss: 0.0018
# Epoch 6/180
# 69/69 [==============================] - 17s 243ms/step - loss: 8.3485e-04 - val_loss: 0.0017
# Epoch 7/180
# 69/69 [==============================] - 17s 253ms/step - loss: 7.7559e-04 - val_loss: 0.0018
# Epoch 8/180
# 69/69 [==============================] - 18s 267ms/step - loss: 7.5274e-04 - val_loss: 0.0017
# Epoch 9/180
# 69/69 [==============================] - 19s 269ms/step - loss: 7.2902e-04 - val_loss: 0.0018
# Epoch 10/180
# 69/69 [==============================] - 18s 262ms/step - loss: 7.6498e-04 - val_loss: 0.0017
# Epoch 11/180
# 69/69 [==============================] - 19s 276ms/step - loss: 7.1707e-04 - val_loss: 0.0016
# Epoch 12/180
# 69/69 [==============================] - 20s 284ms/step - loss: 6.9613e-04 - val_loss: 0.0014
# Epoch 13/180
# 69/69 [==============================] - 18s 261ms/step - loss: 7.0394e-04 - val_loss: 0.0016
# Epoch 14/180
# 69/69 [==============================] - 19s 273ms/step - loss: 7.4344e-04 - val_loss: 0.0017
# Epoch 15/180
# 69/69 [==============================] - 18s 257ms/step - loss: 7.0419e-04 - val_loss: 0.0018
# Epoch 16/180
# 69/69 [==============================] - 19s 274ms/step - loss: 7.3339e-04 - val_loss: 0.0013
# Epoch 17/180
# 69/69 [==============================] - 17s 252ms/step - loss: 6.3748e-04 - val_loss: 0.0012
# Epoch 18/180
# 69/69 [==============================] - 18s 267ms/step - loss: 6.2137e-04 - val_loss: 0.0018
# Epoch 19/180
# 69/69 [==============================] - 17s 252ms/step - loss: 6.4514e-04 - val_loss: 0.0013
# Epoch 20/180
# 69/69 [==============================] - 17s 254ms/step - loss: 6.0726e-04 - val_loss: 0.0012
# Epoch 21/180
# 69/69 [==============================] - 19s 278ms/step - loss: 6.2621e-04 - val_loss: 0.0011
# Epoch 22/180
# 69/69 [==============================] - 18s 264ms/step - loss: 6.0070e-04 - val_loss: 0.0013
# Epoch 23/180
# 69/69 [==============================] - 17s 251ms/step - loss: 6.3808e-04 - val_loss: 0.0010
# Epoch 24/180
# 69/69 [==============================] - 19s 270ms/step - loss: 6.1467e-04 - val_loss: 0.0013
# Epoch 25/180
# 69/69 [==============================] - 18s 257ms/step - loss: 5.6163e-04 - val_loss: 0.0013
# Epoch 26/180
# 69/69 [==============================] - 18s 257ms/step - loss: 5.4916e-04 - val_loss: 9.3645e-04
# Epoch 27/180
# 69/69 [==============================] - 19s 270ms/step - loss: 5.5025e-04 - val_loss: 9.9956e-04
# Epoch 28/180
# 69/69 [==============================] - 19s 275ms/step - loss: 5.3204e-04 - val_loss: 7.7499e-04
# Epoch 29/180
# 69/69 [==============================] - 19s 271ms/step - loss: 4.9415e-04 - val_loss: 8.0216e-04
# Epoch 30/180
# 69/69 [==============================] - 19s 270ms/step - loss: 4.9867e-04 - val_loss: 9.1075e-04
# Epoch 31/180
# 69/69 [==============================] - 18s 256ms/step - loss: 5.1697e-04 - val_loss: 9.4790e-04
# Epoch 32/180
# 69/69 [==============================] - 18s 262ms/step - loss: 5.1544e-04 - val_loss: 0.0010
# Epoch 33/180
# 69/69 [==============================] - 17s 252ms/step - loss: 5.0225e-04 - val_loss: 8.7944e-04
# Epoch 34/180
# 69/69 [==============================] - 17s 251ms/step - loss: 5.3338e-04 - val_loss: 7.5764e-04
# Epoch 35/180
# 69/69 [==============================] - 18s 267ms/step - loss: 4.8898e-04 - val_loss: 8.6034e-04
# Epoch 36/180
# 69/69 [==============================] - 18s 265ms/step - loss: 4.7300e-04 - val_loss: 9.7388e-04
# Epoch 37/180
# 69/69 [==============================] - 18s 258ms/step - loss: 4.9282e-04 - val_loss: 8.6129e-04
# Epoch 38/180
# 69/69 [==============================] - 17s 250ms/step - loss: 4.7091e-04 - val_loss: 8.5950e-04
# Epoch 39/180
# 69/69 [==============================] - 17s 248ms/step - loss: 5.2476e-04 - val_loss: 6.4341e-04
# Epoch 40/180
# 69/69 [==============================] - 17s 249ms/step - loss: 4.3936e-04 - val_loss: 7.6575e-04
# Epoch 41/180
# 69/69 [==============================] - 17s 246ms/step - loss: 4.6065e-04 - val_loss: 6.2997e-04
# Epoch 42/180
# 69/69 [==============================] - 17s 251ms/step - loss: 4.6715e-04 - val_loss: 6.7486e-04
# Epoch 43/180
# 69/69 [==============================] - 17s 246ms/step - loss: 4.6393e-04 - val_loss: 7.0645e-04
# Epoch 44/180
# 69/69 [==============================] - 18s 262ms/step - loss: 4.8387e-04 - val_loss: 7.2931e-04
# Epoch 45/180
# 69/69 [==============================] - 18s 258ms/step - loss: 4.5381e-04 - val_loss: 8.8095e-04
# Epoch 46/180
# 69/69 [==============================] - 17s 248ms/step - loss: 4.3890e-04 - val_loss: 5.8130e-04
# Epoch 47/180
# 69/69 [==============================] - 17s 249ms/step - loss: 4.1587e-04 - val_loss: 5.7888e-04
# Epoch 48/180
# 69/69 [==============================] - 17s 246ms/step - loss: 4.2415e-04 - val_loss: 5.4127e-04
# Epoch 49/180
# 69/69 [==============================] - 17s 245ms/step - loss: 4.1780e-04 - val_loss: 7.2806e-04
# Epoch 50/180
# 69/69 [==============================] - 17s 250ms/step - loss: 4.0047e-04 - val_loss: 8.6961e-04
# Epoch 51/180
# 69/69 [==============================] - 18s 256ms/step - loss: 4.1937e-04 - val_loss: 5.3910e-04
# Epoch 52/180
# 69/69 [==============================] - 17s 247ms/step - loss: 4.3432e-04 - val_loss: 9.7668e-04
# Epoch 53/180
# 69/69 [==============================] - 17s 244ms/step - loss: 4.1577e-04 - val_loss: 5.1090e-04
# Epoch 54/180
# 69/69 [==============================] - 17s 254ms/step - loss: 4.1712e-04 - val_loss: 4.3061e-04
# Epoch 55/180
# 69/69 [==============================] - 17s 245ms/step - loss: 4.0906e-04 - val_loss: 7.1178e-04
# Epoch 56/180
# 69/69 [==============================] - 17s 248ms/step - loss: 3.9984e-04 - val_loss: 7.9952e-04
# Epoch 57/180
# 69/69 [==============================] - 17s 252ms/step - loss: 4.2225e-04 - val_loss: 4.5911e-04
# Epoch 58/180
# 69/69 [==============================] - 17s 251ms/step - loss: 3.8754e-04 - val_loss: 6.7901e-04
# Epoch 59/180
# 69/69 [==============================] - 17s 245ms/step - loss: 4.1165e-04 - val_loss: 7.9232e-04
# Epoch 60/180
# 69/69 [==============================] - 17s 248ms/step - loss: 4.0065e-04 - val_loss: 6.2764e-04
# Epoch 61/180
# 69/69 [==============================] - 17s 251ms/step - loss: 3.9831e-04 - val_loss: 5.0902e-04
# Epoch 62/180
# 69/69 [==============================] - 17s 248ms/step - loss: 3.9447e-04 - val_loss: 4.5678e-04
# Epoch 63/180
# 69/69 [==============================] - 18s 257ms/step - loss: 3.7574e-04 - val_loss: 3.9849e-04
# Epoch 64/180
# 69/69 [==============================] - 21s 304ms/step - loss: 3.7872e-04 - val_loss: 3.7621e-04
# Epoch 65/180
# 69/69 [==============================] - 17s 250ms/step - loss: 3.7629e-04 - val_loss: 4.9111e-04
# Epoch 66/180
# 69/69 [==============================] - 18s 267ms/step - loss: 3.7554e-04 - val_loss: 4.4955e-04
# Epoch 67/180
# 69/69 [==============================] - 17s 249ms/step - loss: 3.6165e-04 - val_loss: 5.0427e-04
# Epoch 68/180
# 69/69 [==============================] - 17s 252ms/step - loss: 3.6576e-04 - val_loss: 5.1420e-04
# Epoch 69/180
# 69/69 [==============================] - 19s 274ms/step - loss: 3.6549e-04 - val_loss: 3.8332e-04
# Epoch 70/180
# 69/69 [==============================] - 19s 274ms/step - loss: 3.6787e-04 - val_loss: 3.6720e-04
# Epoch 71/180
# 69/69 [==============================] - 19s 282ms/step - loss: 3.5892e-04 - val_loss: 4.6837e-04
# Epoch 72/180
# 69/69 [==============================] - 18s 257ms/step - loss: 3.4516e-04 - val_loss: 4.2702e-04
# Epoch 73/180
# 69/69 [==============================] - 17s 247ms/step - loss: 3.6670e-04 - val_loss: 5.3849e-04
# Epoch 74/180
# 69/69 [==============================] - 17s 252ms/step - loss: 3.6113e-04 - val_loss: 2.8785e-04
# Epoch 75/180
# 69/69 [==============================] - 18s 257ms/step - loss: 3.5370e-04 - val_loss: 3.6307e-04
# Epoch 76/180
# 69/69 [==============================] - 18s 260ms/step - loss: 3.7025e-04 - val_loss: 3.9333e-04
# Epoch 77/180
# 69/69 [==============================] - 17s 252ms/step - loss: 3.4333e-04 - val_loss: 3.7757e-04
# Epoch 78/180
# 69/69 [==============================] - 18s 262ms/step - loss: 3.4821e-04 - val_loss: 4.0920e-04
# Epoch 79/180
# 69/69 [==============================] - 17s 246ms/step - loss: 3.3282e-04 - val_loss: 5.7142e-04
# Epoch 80/180
# 69/69 [==============================] - 17s 248ms/step - loss: 3.6745e-04 - val_loss: 3.9925e-04
# Epoch 81/180
# 69/69 [==============================] - 17s 246ms/step - loss: 3.4036e-04 - val_loss: 3.8706e-04
# Epoch 82/180
# 69/69 [==============================] - 17s 253ms/step - loss: 3.4638e-04 - val_loss: 4.0136e-04
# Epoch 83/180
# 69/69 [==============================] - 17s 253ms/step - loss: 3.2996e-04 - val_loss: 3.8613e-04
# Epoch 84/180
# 69/69 [==============================] - 18s 254ms/step - loss: 3.4040e-04 - val_loss: 2.9253e-04
# Epoch 85/180
# 69/69 [==============================] - 18s 267ms/step - loss: 3.3157e-04 - val_loss: 3.8893e-04
# Epoch 86/180
# 69/69 [==============================] - 17s 251ms/step - loss: 3.3564e-04 - val_loss: 4.2103e-04
# Epoch 87/180
# 69/69 [==============================] - 17s 249ms/step - loss: 3.5165e-04 - val_loss: 3.6615e-04
# Epoch 88/180
# 69/69 [==============================] - 17s 243ms/step - loss: 3.3270e-04 - val_loss: 4.5289e-04
# Epoch 89/180
# 69/69 [==============================] - 17s 250ms/step - loss: 3.3242e-04 - val_loss: 4.5877e-04
# Epoch 90/180
# 69/69 [==============================] - 17s 248ms/step - loss: 3.7080e-04 - val_loss: 5.3500e-04
# Epoch 91/180
# 69/69 [==============================] - 17s 250ms/step - loss: 3.4041e-04 - val_loss: 3.4521e-04
# Epoch 92/180
# 69/69 [==============================] - 21s 295ms/step - loss: 3.2629e-04 - val_loss: 3.6767e-04
# Epoch 93/180
# 69/69 [==============================] - 17s 251ms/step - loss: 3.2743e-04 - val_loss: 3.0058e-04
# Epoch 94/180
# 69/69 [==============================] - 18s 266ms/step - loss: 3.3352e-04 - val_loss: 4.9291e-04
# Epoch 95/180
# 69/69 [==============================] - 18s 254ms/step - loss: 3.5644e-04 - val_loss: 4.1913e-04
# Epoch 96/180
# 69/69 [==============================] - 17s 253ms/step - loss: 3.1175e-04 - val_loss: 4.3146e-04
# Epoch 97/180
# 69/69 [==============================] - 17s 252ms/step - loss: 3.2542e-04 - val_loss: 3.8354e-04
# Epoch 98/180
# 69/69 [==============================] - 17s 249ms/step - loss: 3.1524e-04 - val_loss: 3.3406e-04
# Epoch 99/180
# 69/69 [==============================] - 17s 253ms/step - loss: 3.1761e-04 - val_loss: 2.7523e-04
# Epoch 100/180
# 69/69 [==============================] - 17s 252ms/step - loss: 3.1087e-04 - val_loss: 3.1697e-04
# Epoch 101/180
# 69/69 [==============================] - 17s 254ms/step - loss: 2.9638e-04 - val_loss: 3.7499e-04
# Epoch 102/180
# 69/69 [==============================] - 18s 261ms/step - loss: 3.0679e-04 - val_loss: 4.0467e-04
# Epoch 103/180
# 69/69 [==============================] - 17s 253ms/step - loss: 3.0629e-04 - val_loss: 4.7955e-04
# Epoch 104/180
# 69/69 [==============================] - 18s 261ms/step - loss: 3.2274e-04 - val_loss: 2.8161e-04
# Epoch 105/180
# 69/69 [==============================] - 19s 276ms/step - loss: 3.1750e-04 - val_loss: 4.0343e-04
# Epoch 106/180
# 69/69 [==============================] - 18s 255ms/step - loss: 3.2203e-04 - val_loss: 3.3407e-04
# Epoch 107/180
# 69/69 [==============================] - 18s 255ms/step - loss: 2.9728e-04 - val_loss: 3.6049e-04
# Epoch 108/180
# 69/69 [==============================] - 17s 253ms/step - loss: 3.0663e-04 - val_loss: 2.6783e-04
# Epoch 109/180
# 69/69 [==============================] - 17s 246ms/step - loss: 3.1809e-04 - val_loss: 3.5022e-04
# Epoch 110/180
# 69/69 [==============================] - 18s 263ms/step - loss: 3.0778e-04 - val_loss: 3.3650e-04
# Epoch 111/180
# 69/69 [==============================] - 17s 250ms/step - loss: 3.0223e-04 - val_loss: 2.7310e-04
# Epoch 112/180
# 69/69 [==============================] - 19s 271ms/step - loss: 3.0064e-04 - val_loss: 4.6948e-04
# Epoch 113/180
# 69/69 [==============================] - 18s 254ms/step - loss: 2.9526e-04 - val_loss: 3.2402e-04
# Epoch 114/180
# 69/69 [==============================] - 18s 261ms/step - loss: 3.0076e-04 - val_loss: 3.5004e-04
# Epoch 115/180
# 69/69 [==============================] - 18s 255ms/step - loss: 3.0510e-04 - val_loss: 3.2025e-04
# Epoch 116/180
# 69/69 [==============================] - 17s 248ms/step - loss: 3.0098e-04 - val_loss: 3.7707e-04
# Epoch 117/180
# 69/69 [==============================] - 18s 269ms/step - loss: 2.8851e-04 - val_loss: 3.8798e-04
# Epoch 118/180
# 69/69 [==============================] - 19s 278ms/step - loss: 2.9399e-04 - val_loss: 3.3158e-04
# Epoch 119/180
# 69/69 [==============================] - 18s 260ms/step - loss: 3.1814e-04 - val_loss: 3.0263e-04
# Epoch 120/180
# 69/69 [==============================] - 17s 249ms/step - loss: 2.9941e-04 - val_loss: 2.9559e-04
# Epoch 121/180
# 69/69 [==============================] - 17s 248ms/step - loss: 2.7374e-04 - val_loss: 3.2657e-04
# Epoch 122/180
# 69/69 [==============================] - 17s 245ms/step - loss: 2.9156e-04 - val_loss: 4.5567e-04
# Epoch 123/180
# 69/69 [==============================] - 17s 253ms/step - loss: 2.7405e-04 - val_loss: 2.9656e-04
# Epoch 124/180
# 69/69 [==============================] - 18s 263ms/step - loss: 2.9437e-04 - val_loss: 3.0275e-04
# Epoch 125/180
# 69/69 [==============================] - 18s 256ms/step - loss: 2.7459e-04 - val_loss: 2.6660e-04
# Epoch 126/180
# 69/69 [==============================] - 18s 254ms/step - loss: 3.0541e-04 - val_loss: 4.7882e-04
# Epoch 127/180
# 69/69 [==============================] - 18s 268ms/step - loss: 2.7648e-04 - val_loss: 6.5582e-04
# Epoch 128/180
# 69/69 [==============================] - 17s 248ms/step - loss: 2.8516e-04 - val_loss: 3.2802e-04
# Epoch 129/180
# 69/69 [==============================] - 17s 249ms/step - loss: 2.8899e-04 - val_loss: 3.5779e-04
# Epoch 130/180
# 69/69 [==============================] - 17s 247ms/step - loss: 2.7253e-04 - val_loss: 3.5539e-04
# Epoch 131/180
# 69/69 [==============================] - 17s 248ms/step - loss: 2.6667e-04 - val_loss: 2.8780e-04
# Epoch 132/180
# 69/69 [==============================] - 17s 249ms/step - loss: 2.6849e-04 - val_loss: 3.0351e-04
# Epoch 133/180
# 69/69 [==============================] - 17s 249ms/step - loss: 2.8181e-04 - val_loss: 3.9467e-04
# Epoch 134/180
# 69/69 [==============================] - 18s 263ms/step - loss: 2.7418e-04 - val_loss: 2.9391e-04
# Epoch 135/180
# 69/69 [==============================] - 18s 255ms/step - loss: 2.7474e-04 - val_loss: 4.3901e-04
# Epoch 136/180
# 69/69 [==============================] - 17s 250ms/step - loss: 2.7371e-04 - val_loss: 2.8657e-04
# Epoch 137/180
# 69/69 [==============================] - 17s 245ms/step - loss: 2.9519e-04 - val_loss: 3.3426e-04
# Epoch 138/180
# 69/69 [==============================] - 17s 253ms/step - loss: 2.7509e-04 - val_loss: 3.1364e-04
# Epoch 139/180
# 69/69 [==============================] - 17s 251ms/step - loss: 2.6360e-04 - val_loss: 4.2548e-04
# Epoch 140/180
# 69/69 [==============================] - 17s 248ms/step - loss: 2.7975e-04 - val_loss: 2.8426e-04
# Epoch 141/180
# 69/69 [==============================] - 17s 251ms/step - loss: 2.7459e-04 - val_loss: 3.9127e-04
# Epoch 142/180
# 69/69 [==============================] - 17s 251ms/step - loss: 2.8560e-04 - val_loss: 3.4892e-04
# Epoch 143/180
# 69/69 [==============================] - 18s 265ms/step - loss: 2.8527e-04 - val_loss: 3.5673e-04
# Epoch 144/180
# 69/69 [==============================] - 19s 273ms/step - loss: 2.7952e-04 - val_loss: 3.2614e-04
# Epoch 145/180
# 69/69 [==============================] - 18s 265ms/step - loss: 2.5646e-04 - val_loss: 2.2808e-04
# Epoch 146/180
# 69/69 [==============================] - 19s 278ms/step - loss: 2.6703e-04 - val_loss: 3.6872e-04
# Epoch 147/180
# 69/69 [==============================] - 18s 262ms/step - loss: 2.6002e-04 - val_loss: 5.9056e-04
# Epoch 148/180
# 69/69 [==============================] - 18s 266ms/step - loss: 2.7166e-04 - val_loss: 2.3821e-04
# Epoch 149/180
# 69/69 [==============================] - 18s 254ms/step - loss: 2.8068e-04 - val_loss: 2.4320e-04
# Epoch 150/180
# 69/69 [==============================] - 19s 267ms/step - loss: 2.6539e-04 - val_loss: 3.0885e-04
# Epoch 151/180
# 69/69 [==============================] - 18s 266ms/step - loss: 2.7129e-04 - val_loss: 2.6715e-04
# Epoch 152/180
# 69/69 [==============================] - 18s 267ms/step - loss: 2.6335e-04 - val_loss: 3.9646e-04
# Epoch 153/180
# 69/69 [==============================] - 17s 251ms/step - loss: 2.5620e-04 - val_loss: 3.3822e-04
# Epoch 154/180
# 69/69 [==============================] - 18s 267ms/step - loss: 2.6285e-04 - val_loss: 3.2917e-04
# Epoch 155/180
# 69/69 [==============================] - 21s 297ms/step - loss: 2.5258e-04 - val_loss: 2.3158e-04
# Epoch 156/180
# 69/69 [==============================] - 18s 260ms/step - loss: 2.6935e-04 - val_loss: 2.7812e-04
# Epoch 157/180
# 69/69 [==============================] - 18s 260ms/step - loss: 2.6239e-04 - val_loss: 3.7560e-04
# Epoch 158/180
# 69/69 [==============================] - 18s 265ms/step - loss: 2.5270e-04 - val_loss: 2.7891e-04
# Epoch 159/180
# 69/69 [==============================] - 18s 266ms/step - loss: 2.4521e-04 - val_loss: 2.1916e-04
# Epoch 160/180
# 69/69 [==============================] - 18s 261ms/step - loss: 2.6616e-04 - val_loss: 3.0900e-04
# Epoch 161/180
# 69/69 [==============================] - 18s 261ms/step - loss: 2.5422e-04 - val_loss: 3.4809e-04
# Epoch 162/180
# 69/69 [==============================] - 18s 257ms/step - loss: 2.5463e-04 - val_loss: 3.7083e-04
# Epoch 163/180
# 69/69 [==============================] - 18s 256ms/step - loss: 2.4888e-04 - val_loss: 3.9161e-04
# Epoch 164/180
# 69/69 [==============================] - 18s 261ms/step - loss: 2.4281e-04 - val_loss: 3.4375e-04
# Epoch 165/180
# 69/69 [==============================] - 17s 251ms/step - loss: 2.4477e-04 - val_loss: 2.8653e-04
# Epoch 166/180
# 69/69 [==============================] - 18s 263ms/step - loss: 2.4230e-04 - val_loss: 3.4947e-04
# Epoch 167/180
# 69/69 [==============================] - 20s 286ms/step - loss: 2.6071e-04 - val_loss: 3.8965e-04
# Epoch 168/180
# 69/69 [==============================] - 18s 257ms/step - loss: 2.6737e-04 - val_loss: 2.7643e-04
# Epoch 169/180
# 69/69 [==============================] - 17s 249ms/step - loss: 2.4180e-04 - val_loss: 2.1856e-04
# Epoch 170/180
# 69/69 [==============================] - 18s 260ms/step - loss: 2.4573e-04 - val_loss: 2.6334e-04
# Epoch 171/180
# 69/69 [==============================] - 18s 256ms/step - loss: 2.5847e-04 - val_loss: 2.3826e-04
# Epoch 172/180
# 69/69 [==============================] - 18s 258ms/step - loss: 2.4838e-04 - val_loss: 2.8191e-04
# Epoch 173/180
# 69/69 [==============================] - 17s 248ms/step - loss: 2.5964e-04 - val_loss: 2.5503e-04
# Epoch 174/180
# 69/69 [==============================] - 17s 248ms/step - loss: 2.5469e-04 - val_loss: 2.3439e-04
# Epoch 175/180
# 69/69 [==============================] - 17s 244ms/step - loss: 2.6729e-04 - val_loss: 2.9471e-04
# Epoch 176/180
# 69/69 [==============================] - 17s 249ms/step - loss: 2.5236e-04 - val_loss: 2.2861e-04
# Epoch 177/180
# 69/69 [==============================] - 17s 247ms/step - loss: 2.4321e-04 - val_loss: 2.8321e-04
# Epoch 178/180
# 69/69 [==============================] - 18s 256ms/step - loss: 2.3933e-04 - val_loss: 3.3011e-04
# Epoch 179/180
# 69/69 [==============================] - 18s 259ms/step - loss: 2.5097e-04 - val_loss: 3.7683e-04
# Epoch 180/180
# 69/69 [==============================] - 18s 254ms/step - loss: 2.4299e-04 - val_loss: 2.4892e-04

# %%
model.save_weights('./checkpoints/final_checkpoint_180')

# %%
model.load_weights('./checkpoints/final_checkpoint_180')

# %%
#使用多头模型 multi_head 对测试集 X_test 进行预测得到的预测结果。

predicted_CPU = model.predict([test_x3,test_x])
predicted_CPU.shape
# Out:
# 43/43 [==============================] - 4s 39ms/step
# (1361, 1)

# %%
plt.figure(figsize = (36,18))
plt.plot(test_y3[100:300], color = 'black', label = 'Close Price')
plt.plot(predicted_CPU[100:300], color = 'green', label = 'Predicted Close Price')
plt.legend(loc='upper right')
plt.title('Close Price Prediction', fontsize=40)
#plt.xticks(range(0,df.shape[0],50),df['Date'].loc[::50],rotation=45)
plt.xlabel('DateTime',fontsize=40)
plt.xticks(fontsize=40)
plt.ylabel('Close Price',fontsize=40)
plt.yticks(fontsize=40)
plt.legend(fontsize=40)
plt.show()

# %%
train_data , test_data = split_dataset(dataset_3 , 0.8)
Test_x3,Test_y3 = create_dataset(test_data)
Test_y3
# Out:
# train_dataset: 5506, test_dataset: 1377
# array([126.8906, 126.85  , 126.92  , ..., 126.16  , 126.0702, 126.07  ],
#       dtype=float32)

# %%
predicted_y = scaler_3.inverse_transform(predicted_CPU)
print(predicted_y)
# Out:
# [[126.83743 ]
#  [126.839584]
#  [126.835144]
#  ...
#  [126.13624 ]
#  [126.1055  ]
#  [126.057846]]

# %%
test_score = numpy.sqrt(mean_squared_error(Test_y3[:], predicted_y[:, 0]))
print('Test Score: %.2f RMSE' % test_score)
# Out:
# Test Score: 0.13 RMSE

# %%
# MAE, 平均绝对误差（  （|预测| - |真实| ）/ 样本个数   ）
from sklearn.metrics import mean_absolute_error
test_score = mean_absolute_error(Test_y3, predicted_y[:,0])
print('Test Score: %.2f MAE' % test_score)
#MSLE, 均方对数误差  MSLE = mean((log(1 + y_pred) - log(1 + y_true))²)
#衡量预测结果与真实值之间的对数差异程度的平均值
from sklearn.metrics import mean_squared_log_error
test_score = mean_squared_log_error(Test_y3, predicted_y[:,0])
print('Test Score: %.2f MSLE' % test_score)
#R-Squared (决定系数)：R-Squared = 1 - (SSR / SST)  
from sklearn.metrics import r2_score
test_score = r2_score(Test_y3, predicted_y[:,0])
print('Test Score: %.2f R^2' % test_score)
#Mean Absolute Percentage Error (MAPE, 平均绝对百分比误差)：
test_score = numpy.mean(numpy.abs((Test_y3 - predicted_y[:,0]) / Test_y3)) * 100
print('Test Score: %.2f%% MAPE' % test_score)
# Mean Percentage Error (MPE, 平均百分比误差)：  特别适用于时间序列数据
#MPE的取值范围是负无穷到正无穷，正值表示预测结果高估，负值表示预测结果低估，0表示预测结果准确。
test_score = numpy.mean((Test_y3 - predicted_y[:,0]) / Test_y3) * 100
print('Test Score: %.2f%% MPE' % test_score)
#相对绝对误差（RAE）：
#RAE的值越小越好，它衡量了模型预测误差与基准模型预测误差的相对性。
def relative_absolute_error(actual_values, predicted_values):
    absolute_errors = numpy.abs(actual_values - predicted_values)
    mean_actual = numpy.mean(actual_values)
    return numpy.sum(absolute_errors) / numpy.sum(numpy.abs(actual_values - mean_actual))
rae = relative_absolute_error(Test_y3, predicted_y[:,0])
print('Test Score: %.2f%% RAE' % rae)
#Median Absolute Error (MedAE, 中位数绝对误差)：
#中位数绝对误差的值越小，表示模型的预测误差越小，模型的性能越好。
from sklearn.metrics import median_absolute_error
test_score = median_absolute_error(Test_y3, predicted_y[:,0])
print('Test Score: %.2f MedAE' % test_score)
# Out:
# Test Score: 0.07 MAE
# Test Score: 0.00 MSLE
# Test Score: 0.96 R^2
# Test Score: 0.06% MAPE
# Test Score: 0.03% MPE
# Test Score: 0.13% RAE
# Test Score: 0.04 MedAE

# %%
import seaborn as sns
sns.kdeplot(Test_y3, label='True Values')
sns.kdeplot(predicted_y[:, 0], label='Predictions')
# sns.kdeplot(predicted_CPU[:, 1], label='Head 2 Predictions')
plt.xlabel('Values')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.hist(Test_y3[:], bins=30, alpha=0.5, label='True Values')
plt.hist(predicted_y[:, 0], bins=30, alpha=0.5, label='Predictions')
# plt.hist(predicted_CPU[:, 1], bins=30, alpha=0.5, label='Head 2 Predictions')
plt.xlabel('Values')
plt.ylabel('Count')
plt.legend()
plt.show()
